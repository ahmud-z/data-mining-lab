# %% [markdown]
# #### Imports Required Libraries

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_csv("Market_Basket_Optimisation.csv")
df.head(2)
# Out:
#     shrimp    almonds avocado vegetables mix green grapes whole weat flour  \
# 0  burgers  meatballs    eggs            NaN          NaN              NaN
# 1  chutney        NaN     NaN            NaN          NaN              NaN
#
#   yams cottage cheese energy drink tomato juice low fat yogurt green tea  \
# 0  NaN            NaN          NaN          NaN            NaN       NaN
# 1  NaN            NaN          NaN          NaN            NaN       NaN
#
#   honey salad mineral water salmon antioxydant juice frozen smoothie spinach  \
# 0   NaN   NaN           NaN    NaN               NaN             NaN     NaN
# 1   NaN   NaN           NaN    NaN               NaN             NaN     NaN
#
#    olive oil
# 0        NaN
# 1        NaN

# %% [markdown]
# #### Replaces 'NaN' values with empty string

# %%
df = df.fillna("")
df.head(2)
# Out:
#     shrimp    almonds avocado vegetables mix green grapes whole weat flour  \
# 0  burgers  meatballs    eggs
# 1  chutney
#
#   yams cottage cheese energy drink tomato juice low fat yogurt green tea  \
# 0
# 1
#
#   honey salad mineral water salmon antioxydant juice frozen smoothie spinach  \
# 0
# 1
#
#   olive oil
# 0
# 1

# %% [markdown]
# #### Encode the dataset into true/false values using tansaction encoder

# %%
te = TransactionEncoder()
encoded_array = te.fit_transform(df.values.tolist())

# %% [markdown]
# #### Convert the encoded array into pandas dataframe

# %%
transaction_df = pd.DataFrame(encoded_array, columns=te.columns_)
transaction_df.head(2)
# Out:
#           asparagus  almonds  antioxydant juice  asparagus  avocado  \
# 0  True       False    False              False      False    False
# 1  True       False    False              False      False    False
#
#    babies food  bacon  barbecue sauce  black tea  ...  turkey  vegetables mix  \
# 0        False  False           False      False  ...   False           False
# 1        False  False           False      False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False             False              False
# 1        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False  False        False     False
# 1             False  False        False     False
#
# [2 rows x 121 columns]

# %% [markdown]
# #### Extract frequent items by using fp-growth algorithm

# %%
frequent_items = fpgrowth(transaction_df, min_support=0.1, use_colnames=True)
frequent_items
# Out:
#      support           itemsets
# 0   1.000000                 ()
# 1   0.179733             (eggs)
# 2   0.238267    (mineral water)
# 3   0.132000        (green tea)
# 4   0.129600             (milk)
# 5   0.170933     (french fries)
# 6   0.174133        (spaghetti)
# 7   0.163867        (chocolate)
# 8   0.179733           (, eggs)
# 9   0.238267  (, mineral water)
# 10  0.132000      (, green tea)
# 11  0.129600           (, milk)
# 12  0.170933   (, french fries)
# 13  0.174133      (, spaghetti)
# 14  0.163867      (, chocolate)

# %% [markdown]
# #### Genreate association rules for frequent items

# %%
rules = association_rules(frequent_items, min_threshold=0.2)
rules
# Out:
# d:\Workspace\University\9th-Semester\data-mining-lab\.venv\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
#        antecedents      consequents  antecedent support  consequent support  \
# 0           (eggs)               ()            0.179733            1.000000
# 1               ()  (mineral water)            1.000000            0.238267
# 2  (mineral water)               ()            0.238267            1.000000
# 3      (green tea)               ()            0.132000            1.000000
# 4           (milk)               ()            0.129600            1.000000
# 5   (french fries)               ()            0.170933            1.000000
# 6      (spaghetti)               ()            0.174133            1.000000
# 7      (chocolate)               ()            0.163867            1.000000
#
#     support  confidence  lift  representativity  leverage  conviction  \
# 0  0.179733    1.000000   1.0               1.0       0.0         inf
# 1  0.238267    0.238267   1.0               1.0       0.0         1.0
# 2  0.238267    1.000000   1.0               1.0       0.0         inf
# 3  0.132000    1.000000   1.0               1.0       0.0         inf
# 4  0.129600    1.000000   1.0               1.0       0.0         inf
# 5  0.170933    1.000000   1.0               1.0       0.0         inf
# 6  0.174133    1.000000   1.0               1.0       0.0         inf
# 7  0.163867    1.000000   1.0               1.0       0.0         inf
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0            0.0  0.179733        0.0    0.589867
# 1            0.0  0.238267        0.0    0.619133
# 2            0.0  0.238267        0.0    0.619133
# 3            0.0  0.132000        0.0    0.566000
# 4            0.0  0.129600        0.0    0.564800
# 5            0.0  0.170933        0.0    0.585467
# 6            0.0  0.174133        0.0    0.587067
# 7            0.0  0.163867        0.0    0.581933

# %% [markdown]
# #### Print association rules with necessary columns

# %%
rules[["antecedents", "consequents", "support", "confidence"]]
# Out:
#        antecedents      consequents   support  confidence
# 0           (eggs)               ()  0.179733    1.000000
# 1               ()  (mineral water)  0.238267    0.238267
# 2  (mineral water)               ()  0.238267    1.000000
# 3      (green tea)               ()  0.132000    1.000000
# 4           (milk)               ()  0.129600    1.000000
# 5   (french fries)               ()  0.170933    1.000000
# 6      (spaghetti)               ()  0.174133    1.000000
# 7      (chocolate)               ()  0.163867    1.000000
