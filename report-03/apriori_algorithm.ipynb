# %%
import pandas as pd
from mlxtend.preprocessing import  TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df =pd.read_csv('greenbasket.csv')
df.head()
# Out:
#    Transaction                      Product1                      Product2  \
# 0            1  Bedside Table African Cherry                  Chicken Meat
# 1            2          Annibale Colombo Bed  Bedside Table African Cherry
# 2            3           Calvin Klein CK One       Chanel Coco Noir Eau De
# 3            4           Calvin Klein CK One       Chanel Coco Noir Eau De
# 4            5           Calvin Klein CK One       Chanel Coco Noir Eau De
#
#                                     Product3      Product4     Product5  \
# 0                         Green Chili Pepper     Ice Cream         Rice
# 1  Knoll Saarinen Executive Conference Chair  Chicken Meat     Potatoes
# 2                                 Beef Steak      Cat Food  Cooking Oil
# 3                      Annibale Colombo Sofa    Beef Steak     Cat Food
# 4  Knoll Saarinen Executive Conference Chair    Beef Steak     Cat Food
#
#       Product6               Product7           Product8  \
# ...

# %%
print("Column Name  Total Null")
df.isnull().sum()
# Out:
# Column Name  Total Null
# Transaction       0
# Product1          0
# Product2          0
# Product3          0
# Product4          0
# Product5          0
# Product6          0
# Product7          0
# Product8          0
# Product9          0
# Product10         3
# Product11      1008
# Product12      2056
# Product13      3087
# Product14      4107
# Product15      5141
# Product16      6197
# Product17      6297
# Product18      6427
# Product19      6562
# Product20      6711
# Product21      6855
# Product22      6994
# dtype: int64

# %%
df.drop("Transaction", axis=1, inplace=True)
df.head()
# Out:
#                        Product1                      Product2  \
# 0  Bedside Table African Cherry                  Chicken Meat
# 1          Annibale Colombo Bed  Bedside Table African Cherry
# 2           Calvin Klein CK One       Chanel Coco Noir Eau De
# 3           Calvin Klein CK One       Chanel Coco Noir Eau De
# 4           Calvin Klein CK One       Chanel Coco Noir Eau De
#
#                                     Product3      Product4     Product5  \
# 0                         Green Chili Pepper     Ice Cream         Rice
# 1  Knoll Saarinen Executive Conference Chair  Chicken Meat     Potatoes
# 2                                 Beef Steak      Cat Food  Cooking Oil
# 3                      Annibale Colombo Sofa    Beef Steak     Cat Food
# 4  Knoll Saarinen Executive Conference Chair    Beef Steak     Cat Food
#
#       Product6               Product7           Product8  \
# 0  Soft Drinks             Strawberry     Mug Tree Stand
# ...

# %%
df.fillna("", inplace=True)
df.values.tolist()
# Out:
# [['Bedside Table African Cherry',
#   'Chicken Meat',
#   'Green Chili Pepper',
#   'Ice Cream',
#   'Rice',
#   'Soft Drinks',
#   'Strawberry',
#   'Mug Tree Stand',
#   'Plate',
#   'Slotted Turner',
#   'Spoon',
#   'Green and Black Glasses',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Annibale Colombo Bed',
#   'Bedside Table African Cherry',
#   'Knoll Saarinen Executive Conference Chair',
#   'Chicken Meat',
#   'Potatoes',
#   'Strawberry',
#   'House Showpiece Plant',
#   'Carbon Steel Wok',
#   'Silver Pot With Glass Cap',
#   'Tray',
#   'Green and Black Glasses',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Calvin Klein CK One',
#   'Chanel Coco Noir Eau De',
#   'Beef Steak',
#   'Cat Food',
#   'Cooking Oil',
#   'Eggs',
#   'Fish Steak',
#   'Green Bell Pepper',
#   'Ice Cream',
#   'Citrus Squeezer Yellow',
#   'Fork',
#   'Lunch Box',
#   'Silver Pot With Glass Cap',
# ...

# %%
te = TransactionEncoder()
te_array = te.fit_transform(df.values.tolist())
te_array[:3]
# Out:
# array([[ True, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#          True,  True, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False,  True,
#         False, False, False, False, False, False,  True, False, False,
#         False, False,  True, False,  True,  True, False,  True,  True,
#         False, False, False, False, False, False, False, False, False],
#        [ True,  True, False, False, False, False,  True, False, False,
#         False, False, False, False,  True, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
# ...

# %%
te.columns_
# Out:
# ['',
#  'Annibale Colombo Bed',
#  'Annibale Colombo Sofa',
#  'Apple',
#  'Attitude Super Leaves Hand Soap',
#  'Bamboo Spatula',
#  'Bedside Table African Cherry',
#  'Beef Steak',
#  'Black Aluminium Cup',
#  'Black Sun Glasses',
#  'Black Whisk',
#  'Boxed Blender',
#  'Calvin Klein CK One',
#  'Carbon Steel Wok',
#  'Cat Food',
#  'Chanel Coco Noir Eau De',
#  'Chicken Meat',
#  'Chopping Board',
#  'Citrus Squeezer Yellow',
#  'Classic Sun Glasses',
#  'Cooking Oil',
#  'Cucumber',
#  'Decoration Swing',
#  "Dior J'adore",
#  'Dog Food',
#  'Dolce Shine Eau de',
#  'Egg Slicer',
#  'Eggs',
#  'Electric Stove',
#  'Family Tree Photo Frame',
#  'Fine Mesh Strainer',
#  'Fish Steak',
#  'Fork',
#  'Glass',
#  'Grater Black',
#  'Green Bell Pepper',
#  'Green Chili Pepper',
#  'Green and Black Glasses',
#  'Gucci Bloom Eau de',
#  'Hand Blender',
#  'Honey Jar',
#  'House Showpiece Plant',
#  'Ice Cream',
#  'Ice Cube Tray',
#  'Juice',
#  'Kitchen Sieve',
#  'Kiwi',
#  'Knife',
# ...

# %%
transaction_df = pd.DataFrame(te_array, columns=te.columns_)
transaction_df.head()
# Out:
#          Annibale Colombo Bed  Annibale Colombo Sofa  Apple  \
# 0  True                 False                  False  False
# 1  True                  True                  False  False
# 2  True                 False                  False  False
# 3  True                 False                   True  False
# 4  True                 False                  False  False
#
#    Attitude Super Leaves Hand Soap  Bamboo Spatula  \
# 0                            False           False
# 1                            False           False
# 2                            False           False
# 3                            False           False
# 4                            False           False
#
#    Bedside Table African Cherry  Beef Steak  Black Aluminium Cup  \
# 0                          True       False                False
# 1                          True       False                False
# 2                         False        True                False
# ...

# %%
freq_items = apriori(transaction_df, min_support=0.1, use_colnames=True)
freq_items
# Out:
#       support                               itemsets
# 0    0.896667                                     ()
# 1    0.175128                 (Annibale Colombo Bed)
# 2    0.174615                (Annibale Colombo Sofa)
# 3    0.176538                                (Apple)
# 4    0.165513      (Attitude Super Leaves Hand Soap)
# ..        ...                                    ...
# 156  0.144744  (, Vaseline Men Body and Face Lotion)
# 157  0.149231                              (, Water)
# 158  0.150000   (, Wooden Bathroom Sink With Mirror)
# 159  0.148846                 (, Wooden Rolling Pin)
# 160  0.147949                      (, Yellow Peeler)
#
# [161 rows x 2 columns]

# %%
rules = association_rules(freq_items, min_threshold=0.1)
rules
# Out:
#                             antecedents              consequents  \
# 0                                    ()   (Annibale Colombo Bed)
# 1                (Annibale Colombo Bed)                       ()
# 2                                    ()  (Annibale Colombo Sofa)
# 3               (Annibale Colombo Sofa)                       ()
# 4                                    ()                  (Apple)
# ..                                  ...                      ...
# 155  (Wooden Bathroom Sink With Mirror)                       ()
# 156                                  ()     (Wooden Rolling Pin)
# 157                (Wooden Rolling Pin)                       ()
# 158                                  ()          (Yellow Peeler)
# 159                     (Yellow Peeler)                       ()
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.896667            0.175128  0.143846    0.160423  0.916033
# ...

# %%
rules[['antecedents', 'consequents', 'support', 'confidence']]
# Out:
#                             antecedents              consequents   support  \
# 0                                    ()   (Annibale Colombo Bed)  0.143846
# 1                (Annibale Colombo Bed)                       ()  0.143846
# 2                                    ()  (Annibale Colombo Sofa)  0.145897
# 3               (Annibale Colombo Sofa)                       ()  0.145897
# 4                                    ()                  (Apple)  0.146538
# ..                                  ...                      ...       ...
# 155  (Wooden Bathroom Sink With Mirror)                       ()  0.150000
# 156                                  ()     (Wooden Rolling Pin)  0.148846
# 157                (Wooden Rolling Pin)                       ()  0.148846
# 158                                  ()          (Yellow Peeler)  0.147949
# 159                     (Yellow Peeler)                       ()  0.147949
#
#      confidence
# 0      0.160423
# 1      0.821376
# ...
